# %%
adj = input("Adjective: ")
verb1= input("Verb: ")
verb2= input("Verb: ")
name= input("Person Name: ")

# %%
madlib =f"Computer Programming is so {adj}. It makes me so happy all the time that I love to {verb1} and {verb2} like the great {name}."
print(madlib)
# Out:
# Computer Programming is so interesting. It makes me so happy all the time that I love to play and eat like the great Petuk.
