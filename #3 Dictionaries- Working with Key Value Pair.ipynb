# %%
student = {'name':'Sohan', 'age':31, 'job':'Software Engineer'}
print(student)
# Out:
# {'name': 'Sohan', 'age': 31, 'job': 'Software Engineer'}

# %%
print(student.get('name'))
print(student.get('Phone', 'Phone No. not found'))
# Out:
# Sohan
# Phone No. not found

# %%
student['phone']='0168-0088'
student['name']='Sohan'
print(student)
# Out:
# {'name': 'Sohan', 'age': 31, 'job': 'Software Engineer', 'phone': '0168-0088'}

# %%
del student['phone']
print(student)
# Out:
# {'name': 'Sohan', 'age': 31, 'job': 'Software Engineer'}

# %%
print(len(student.keys()))
# Out:
# 3

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'job'])

# %%
print(student.items())
# Out:
# dict_items([('name', 'Sohan'), ('age', 31), ('job', 'Software Engineer')])

# %%
for key,value in student.items():
    print(key,value)
# Out:
# name Sohan
# age 31
# job Software Engineer
