# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')
print(df.dtypes)

# %%
print(df)

# %%
#Read Header
df.columns

# %%
#Read Column Top 5
print(df['Name'][0:5])

# %%
#Read Selected column
print(df[['Name','Type 1','HP']])

# %%
 #Read Selected Row
print(df.head(4))
#print(df.iloc[1:4])

# %%
df.describe()

# %%
#sorting
df.sort_values(['Type 1','HP'])

# %%
#making changes to data
df['Total']= df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']+df['Generation']
df.head(5)

# %%
#Save Updated data
#df.to_csv('modified_data.csv', index=False)
#df.to_excel('modified_data.xlsx', index=False)
#df.to_csv('modified_data.txt', index=False, sep='\t')

# %%
#Filtering Data
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP']>50) ]
new_df.reset_index(drop=True, inplace=True)
new_df

# %%
#Name Filter for String
df.loc[df['Name'].str.contains('Mega')]

# %%
#Conditional Changes
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
df.head(10)

# %%
df.loc[df['Total']>500, ['Generation','Legendary']]=='TEST VALUE'

# %%
Df2=pd.read_csv('modified_data.csv')  #Aggregating

# %%
df2.groupby(['Type 1']).mean().sort_values('Defence', ascending=False)

# %%
df.groupby(['Type 1']).count()

# %%
#Working with large dataset
for ef in pd.read_csv('modified_data.csv', chunksize=5):
print(ef)
