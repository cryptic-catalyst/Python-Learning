# %%
import os
os.environ['PYTHONHASHSEED'] = '0'
import os
os.environ['PYTHONHASHSEED'] = '0'
# %pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.21.0-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# ...
# Using cached tensorflow-2.21.0-cp311-cp311-win_amd64.whl (350.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas matplotlib tensorflow
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.1 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------------------------- ---- 2.1/2.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 10.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.0 MB 12.2 MB/s eta 0:00:01
# ...

# %%
# %pip install tensorflow-cpu
# Out:
# ...
#   Using cached tensorflow_cpu-2.21.0-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# ...
#    ---------------------------------------- 0.0/350.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/350.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/350.8 MB ? eta -:--:--
#    ---------------------------------------- 0.8/350.8 MB 1.5 MB/s eta 0:03:50
#    ---------------------------------------- 1.6/350.8 MB 2.6 MB/s eta 0:02:14
#    ---------------------------------------- 2.1/350.8 MB 2.6 MB/s eta 0:02:17
#    ---------------------------------------- 3.1/350.8 MB 2.9 MB/s eta 0:01:59
#    ---------------------------------------- 4.2/350.8 MB 3.4 MB/s eta 0:01:44
# ...

# %%
import pandas as pd
import random as python_random
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
python_random.seed(0)
tf.random.set_seed(0)
# Out:
# [TensorFlow DLL Diagnostic] Analyzing: D:\Python-Learning\.venv\Lib\site-packages\tensorflow\python\_pywrap_tensorflow_internal.pyd
# [Error] Failed to load _pywrap_tensorflow_common.dll: INITIALIZATION FAILED (0x45A) - The DLL's DllMain returned false.
#     Hint: This often happens if your CPU lacks required instructions (like AVX/AVX2)
#     or if the Microsoft Visual C++ Redistributable is outdated/missing.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File D:\Python-Learning\.venv\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:74
#      73 try:
# ---> 74   from tensorflow.python._pywrap_tensorflow_internal import *
#      75 # This try catch logic is because there is no bazel equivalent for py_extension.
#      76 # Externally in opensource we must enable exceptions to load the shared object
# ...

# %%
df_train = pd.read_csv(r"D:\Python-Learning\UNIMIB Deep Learning LAB\california_housing_train.csv")
#comma separated values
#dataframe

# %%
df_test =pd.read_csv(r"D:\Python-Learning\UNIMIB Deep Learning LAB\california_housing_train.csv")
df_test.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#x_train y_train x_test y_test
x_train = df_train.drop('median_house_value', axis=1).to_numpy()
y_train = df_train['median_house_value'].to_numpy()

x_test = df_test.drop('median_house_value', axis=1).to_numpy()
y_test = df_test['median_house_value'].to_numpy()

# %%
x_train.shape
# Out:
# (17000, 8)

# %%
model = keras.Sequential()
model.add((keras.layes.Input(shape=(8,))))
model.add(keras.layers.Dense(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model = keras.Sequential()
#       2 model.add((keras.layes.Input(shape=(8,))))
#       3 model.add(keras.layers.Dense(1))
#
# NameError: name 'keras' is not defined

# %%
model.compile(loss=keras.losses.MeanSquaredError(),
              optimizer=keras.optimizers.RMSprop(learning_rate=0.1
                                                 )
# Out:
#   Cell In[8], line 3
#     )
#      ^
# SyntaxError: incomplete input

# %%
#define a nueral netrwork that takes as input the  8 attributes of a neighborhood
#returns one outpur: the median house value
