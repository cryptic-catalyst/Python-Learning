# %%
import numpy as np
rng1=np.random.default_rng()
rng1.random()
# Out:
# 0.7149634162541748

# %%
rng2=np.random.default_rng()
rng2.random()
# Out:
# 0.25542335224244295

# %%
rng=np.random.default_rng()
rng.random()
# Out:
# 0.4817653048728886

# %%
rng.standard_normal(10)
# Out:
# array([-0.88164365,  0.20486425, -1.26570908, -0.72585308,  0.28147457,
#        -0.40094748,  0.94328574,  0.76301676, -1.21229127,  1.96389706])

# %%
rng.integers(low=0, high=10, size=5)
# Out:
# array([3, 5, 9, 0, 3])

# %%
import numpy as np
import secrets
secrets.randbits(128)
# Out:
# 116521164198801556265929360000179858183

# %%
rng11=np.random.default_rng(37263097010480016776552086208060604907)
rng11.random()
# Out:
# 0.12225809165448365

# %%
rng22=np.random.default_rng(37263097010480016776552086208060604907)
rng22.random()
# Out:
# 0.12225809165448365

# %%
rngA = np.random.default_rng(100)
rngA.random()
# Out:
# 0.8349816305020089

# %%
rngB = np.random.default_rng(101)
rngB.random()
# Out:
# 0.9435325056105539

# %%
import numpy as np
rng12345 = np.random.default_rng(12345)
print (rng12345)
# Out:
# Generator(PCG64)

# %%
rfloat = rng12345.random()
rfloat
# Out:
# 0.22733602246716966

# %%
type(rfloat)
# Out:
# float

# %%
rints = rng12345.integers(low=0, high=10, size=3)
rints
# Out:
# array([7, 3, 2])

# %%
type(rints[0])
# Out:
# numpy.int64

# %%
rng3= np.random.default_rng(seed=42)
arr1= rng3.random((3, 3))
arr1
# Out:
# array([[0.77395605, 0.43887844, 0.85859792],
#        [0.69736803, 0.09417735, 0.97562235],
#        [0.7611397 , 0.78606431, 0.12811363]])

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
type(rng3)
# Out:
# numpy.random._generator.Generator

# %%
import numpy as np
rng33= np.random.default_rng(seed=22)
arr11= rng33.random((3, 3))
arr11
# Out:
# array([[0.36634692, 0.19929538, 0.08855837],
#        [0.65319169, 0.45933704, 0.98767562],
#        [0.85156807, 0.83696132, 0.05143877]])

# %%
rng333= np.random.default_rng(seed=22)
arr111= rng333.random((3, 3))
arr111
# Out:
# array([[0.36634692, 0.19929538, 0.08855837],
#        [0.65319169, 0.45933704, 0.98767562],
#        [0.85156807, 0.83696132, 0.05143877]])

# %%
if(rng33 == rng333):
    print("Both Seeds same")
else:
    print("Both Seeds different")
# Out:
# Both Seeds different
