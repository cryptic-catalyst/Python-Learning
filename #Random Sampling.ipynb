# %%
import numpy as np
rng1=np.random.default_rng()
rng1.random()
# Out:
# 0.9172036479824403

# %%
rng2=np.random.default_rng()
rng2.random()
# Out:
# 0.8919284169036918

# %%
rng=np.random.default_rng()
rng.random()
# Out:
# 0.6857125145129602

# %%
rng.standard_normal(10)
# Out:
# array([-0.48214994,  1.20933078,  0.31450317, -0.53832552, -0.07034746,
#         0.05516378, -0.17798465, -1.81861509, -0.32469948, -1.17765143])

# %%
rng.integers(low=0, high=10, size=5)
# Out:
# array([2, 3, 7, 6, 1])

# %%
import numpy as np
import secrets
secrets.randbits(128)
# Out:
# 262072296326689207150409118103287736962

# %%
rng11=np.random.default_rng(37263097010480016776552086208060604907)
rng11.random()
# Out:
# 0.12225809165448365

# %%
rng22=np.random.default_rng(37263097010480016776552086208060604907)
rng22.random()
# Out:
# 0.12225809165448365

# %%
rngA = np.random.default_rng(100)
rngA.random()
# Out:
# 0.8349816305020089

# %%
rngB = np.random.default_rng(101)
rngB.random()
# Out:
# 0.9435325056105539

# %%
import numpy as np
rng12345 = np.random.default_rng(12345)
print (rng12345)
# Out:
# Generator(PCG64)

# %%
rfloat = rng12345.random()
rfloat
# Out:
# 0.5983087535871898

# %%
type(rfloat)
# Out:
# float

# %%
rints = rng12345.integers(low=0, high=10, size=3)
rints
# Out:
# array([2, 1, 2])

# %%
type(rints[0])
# Out:
# numpy.int64

# %%
rng3= np.random.default_rng(seed=42)
arr1= rng3.random((3, 3))
arr1
# Out:
# array([[0.77395605, 0.43887844, 0.85859792],
#        [0.69736803, 0.09417735, 0.97562235],
#        [0.7611397 , 0.78606431, 0.12811363]])

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
type(rng3)
# Out:
# numpy.random._generator.Generator
