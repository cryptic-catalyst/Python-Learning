# %%
print("HI")
# Out:
# HI

# %%
my_name="SOHANUR"
print("My name is \n" + my_name)
# Out:
# My name is
# SOHANUR

# %%
print(my_name.upper().isupper())
print(my_name.upper())
print(my_name.lower())
# Out:
# True
# SOHANUR
# sohanur

# %%
print(len(my_name))
# Out:
# 7

# %%
print(my_name[2])
# Out:
# H

# %%
print(my_name.index("H"))
# Out:
# 2

# %%
zoo_name="Elephant Academy"
print(zoo_name)
# Out:
# Elephant Academy

# %%
print(zoo_name.replace("Elephant","Tiger"))
# Out:
# Tiger Academy

# %%
my_num=10
print(my_num)
# Out:
# 10

# %%
print(pow(my_num,2))
# Out:
# 100

# %%
my_num2= print(round(pow(my_num,2.1)))
# Out:
# 126

# %%
from math import *
my_num3=10.454
print(floor(my_num3))
# Out:
# 10

# %%
print(ceil(my_num3))
# Out:
# 11

# %%
color = input("Enter color: \n")
actor = input("Enter actor: \n")

print("My TV is: ", color)
print("My favourite acor is ", actor )
# Out:
# My TV is:  Blue
# My favourite acor is  Sakib Khan

# %%
friends = ["Saju", "Dumba", "Mota", "Tonu", "Mirki"]
print(friends[2:4])
# Out:
# ['Mota', 'Tonu']

# %%
f_number=[2,4,6,7,10]
friends.extend(f_number)
print(friends)
# Out:
# ['Saju', 'Dumba', 'Mota', 'Tonu', 'Mirki', 2, 4, 6, 7, 10]

# %%
friends.append("Tarek BGB")

# %%
friends
# Out:
# ['Saju', 'Dumba', 'Mota', 'Tonu', 'Mirki', 2, 4, 6, 7, 10, 'Tarek BGB']

# %%
#tuple
coordinates=(4, 5)
print(coordinates[1])
# Out:
# 5

# %%
#list in a tuple
ordinate=[(1, 2),(2,3),(3,4),(4,5)]
print(ordinate[1])
# Out:
# (2, 3)

# %%
#function
def say_hi(name, age):
    print("Hello " + name +", Your age is: " + age)

# %%
say_hi("Sohan", "31")
say_hi("Moon", "29")
# Out:
# Hello Sohan, Your age is: 31
# Hello Moon, Your age is: 29

# %%
#Return Statement
def cube(number):
    return number ** 3

# %%
result=cube(int(input()))
result
# Out:
# 8000

# %%
#If Statement
is_male = True
is_tall = False
if(is_male or is_tall):
    print("Male or Tall")
else:
    print("Female")
# Out:
# Male or Tall

# %%
is_male = True
is_tall = False
if(is_male and is_tall):
    print("Male or Tall")
else:
    print("Female")
# Out:
# Female

# %%
#If Statement & Comparison
def max_num( num1, num2, num3):
    if (num1>=num2) and (num1>=num3):
        print(num1, " is the maximum number")
    elif (num2>=num1) and (num2>=num3):
        print(num2, " is the maximum number")
    else:
        print(num3, " is the maximum number")

# %%
print(max_num(10,50, 20))
# Out:
# 50  is the maximum number
# None

# %%
#Bulding Calculator
num1 = float(input("Enter the first number: "))
op = input("Enter the operator: ")
num2 = float(input("Enter the second number: "))
if(op=="+"):
    print(num1 + num2)
elif(op== "-"):
    print(num1 - num2)
elif(op=="*"):
    print(num1 * num2)
elif(op=="/"):
    print(num1 / num2)
else:
    print("Invalid operator")
# Out:
# 20.0

# %%
#Dictionaries
