# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\USER\PyCharmMiscProject\Python A to Z\Python A to Z\#L18 Survery_Public.csv", index_col='Respondent')
df_schema = pd.read_csv(r"C:\Users\USER\PyCharmMiscProject\Python A to Z\Python A to Z\#L18 Survey_Schema.csv", index_col='Column')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9828\3661830568.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\USER\PyCharmMiscProject\Python A to Z\Python A to Z\#L18 Survery_Public.csv", index_col='Respondent')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\USER\PyCharmMiscProject\Python A to Z\Python A to Z\#L18 Survery_Public.csv", index_col='Respondent')
#       2 df_schema = pd.read_csv(r"C:\Users\USER\PyCharmMiscProject\Python A to Z\Python A to Z\#L18 Survey_Schema.csv", index_col='Column')
#
# ...
