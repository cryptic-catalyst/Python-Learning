# %%
from encodings.idna import ace_prefix

#collect string n test input
raw_input = input("Please enter your name: ")
if len(raw_input) <= 3:
    print("Your name is too short")
    print("Enter a larger name ")
else:
    print("Your name has more than 03 characters")
# Out:
# Your name has more than 03 characters

# %%
#integer input
number = int(input("Enter a number: "))
if(number%2 == 0):
    print(number, " is a even number")
else:
    print(number, " is a odd number")
# Out:
# 17  is a odd number

# %%
#triangle type
side1=int(input("Enter length of side 1: "))
side2=int(input("Enter length of side 2: "))
side3=int(input("Enter length of side 3: "))
if(side1!=side2 and side2!=side3 and side1 != side3):
    print("This is a scalene triangle")
elif(side1==side2 and side2==side3):
    print("This is a equilateral triangle")
else:
    print("This is a isosceles triangle")
# Out:
# This is a scalene triangle
